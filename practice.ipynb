# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_cohort_data.csv")

# %%
df.sample(5)
# Out:
#       order_id customer_id  order_date  ... customer_segment sales_amount discount
# 166  ORD_10166    CUST_128  2024-06-15  ...              SMB       323.31      0.1
# 74   ORD_10074    CUST_146  2024-03-15  ...         Consumer       435.99      0.0
# 173  ORD_10173    CUST_120  2024-06-22  ...         Consumer       205.10      0.1
# 160  ORD_10160    CUST_115  2024-06-09  ...         Consumer       514.28      0.0
# 199  ORD_10199    CUST_122  2024-07-18  ...              SMB       163.72      0.0
#
# [5 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          200 non-null    str
#  1   customer_id       200 non-null    str
#  2   order_date        200 non-null    str
#  3   region            200 non-null    str
#  4   category          200 non-null    str
#  5   customer_segment  200 non-null    str
#  6   sales_amount      200 non-null    float64
#  7   discount          183 non-null    float64
# dtypes: float64(2), str(6)
# memory usage: 22.1 KB

# %%
df.describe()
# Out:
#        sales_amount    discount
# count    200.000000  183.000000
# mean     399.738950    0.056557
# std      300.340069    0.062552
# min       10.580000    0.000000
# 25%      144.337500    0.000000
# 50%      341.795000    0.050000
# 75%      537.065000    0.100000
# max     1189.680000    0.200000

# %%
df.isna().sum()
# Out:
# order_id             0
# customer_id          0
# order_date           0
# region               0
# category             0
# customer_segment     0
# sales_amount         0
# discount            17
# dtype: int64

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
df['order_year'] = df['order_date'].dt.year

# %%
df['order_month'] = df['order_date'].dt.month

# %%
df['order_day'] = df['order_date'].dt.day

# %%
df['discount'].isnull().sum()
# Out:
# np.int64(17)

# %%
df['discount'].describe()
# Out:
# count    183.000000
# mean       0.056557
# std        0.062552
# min        0.000000
# 25%        0.000000
# 50%        0.050000
# 75%        0.100000
# max        0.200000
# Name: discount, dtype: float64

# %%
sns.boxplot(df['discount'])
# Out:
# <Axes: ylabel='discount'>

# %%
final_df = df.copy()
final_df["discount"] = df["discount"].fillna(df["discount"].mean())

# %%
final_df.sample(10)
# Out:
#       order_id customer_id order_date  ... order_year order_month order_day
# 145  ORD_10145    CUST_100 2024-05-25  ...       2024           5        25
# 166  ORD_10166    CUST_128 2024-06-15  ...       2024           6        15
# 178  ORD_10178    CUST_139 2024-06-27  ...       2024           6        27
# 17   ORD_10017    CUST_129 2024-01-18  ...       2024           1        18
# 22   ORD_10022    CUST_108 2024-01-23  ...       2024           1        23
# 156  ORD_10156    CUST_109 2024-06-05  ...       2024           6         5
# 148  ORD_10148    CUST_111 2024-05-28  ...       2024           5        28
# 7    ORD_10007    CUST_109 2024-01-08  ...       2024           1         8
# 95   ORD_10095    CUST_105 2024-04-05  ...       2024           4         5
# 122  ORD_10122    CUST_143 2024-05-02  ...       2024           5         2
#
# [10 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_date', 'region', 'category',
#        'customer_segment', 'sales_amount', 'discount', 'order_year',
#        'order_month', 'order_day'],
#       dtype='str')
